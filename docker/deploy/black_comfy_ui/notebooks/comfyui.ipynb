# %% [markdown]
# Git clone the repo and install the requirements. (ignore the pip errors about protobuf)

# %% [markdown]
# # Install

# %% [markdown]
# ### Vars

# %%
USE_GOOGLE_DRIVE = False  #@param {type:"boolean"}
UPDATE_COMFY_UI = True  #@param {type:"boolean"}
USE_COMFYUI_MANAGER = True  #@param {type:"boolean"}
INSTALL_CUSTOM_NODES_DEPENDENCIES = True  #@param {type:"boolean"}
WORKSPACE = f"/workspace/appz/ComfyUI"  #@param {type:"string"}

# %% [markdown]
# ### Setup

# %%
# #@title Environment Setup

from pathlib import Path

OPTIONS = {}



OPTIONS['USE_GOOGLE_DRIVE'] = USE_GOOGLE_DRIVE
OPTIONS['UPDATE_COMFY_UI'] = UPDATE_COMFY_UI
OPTIONS['USE_COMFYUI_MANAGER'] = USE_COMFYUI_MANAGER
OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES'] = INSTALL_CUSTOM_NODES_DEPENDENCIES

current_dir = !pwd


if OPTIONS['USE_GOOGLE_DRIVE']:
    # !echo "Mounting Google Drive..."
    # %cd /

    from google.colab import drive
    drive.mount('/content/drive')

    WORKSPACE = "/content/drive/MyDrive/ComfyUI"
    # %cd /content/drive/MyDrive

![ ! -d $WORKSPACE ] && echo -= Initial setup ComfyUI =- && git clone https://github.com/comfyanonymous/ComfyUI
# %cd $WORKSPACE

if OPTIONS['UPDATE_COMFY_UI']:
  # !echo -= Updating ComfyUI =-

  # Correction of the issue of permissions being deleted on Google Drive.
  ![ -f ".ci/nightly/update_windows/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/nightly/update_windows/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/nightly/windows_base_files/run_nvidia_gpu.bat" ] && chmod 755 .ci/nightly/windows_base_files/run_nvidia_gpu.bat
  ![ -f ".ci/update_windows/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/update_windows/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/update_windows_cu118/update_comfyui_and_python_dependencies.bat" ] && chmod 755 .ci/update_windows_cu118/update_comfyui_and_python_dependencies.bat
  ![ -f ".ci/update_windows/update.py" ] && chmod 755 .ci/update_windows/update.py
  ![ -f ".ci/update_windows/update_comfyui.bat" ] && chmod 755 .ci/update_windows/update_comfyui.bat
  ![ -f ".ci/update_windows/README_VERY_IMPORTANT.txt" ] && chmod 755 .ci/update_windows/README_VERY_IMPORTANT.txt
  ![ -f ".ci/update_windows/run_cpu.bat" ] && chmod 755 .ci/update_windows/run_cpu.bat
  ![ -f ".ci/update_windows/run_nvidia_gpu.bat" ] && chmod 755 .ci/update_windows/run_nvidia_gpu.bat

  # !git pull

# !echo -= Install dependencies =-
# !pip3 install accelerate
# !pip3 install einops transformers>=4.25.1 safetensors>=0.3.0 aiohttp pyyaml Pillow scipy tqdm psutil
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip3 install torchsde
# !pip3 install kornia>=0.7.1 spandrel
# !pip3 install tqdm

if OPTIONS['USE_COMFYUI_MANAGER']:
  # %cd custom_nodes

  # Correction of the issue of permissions being deleted on Google Drive.
  ![ -f "ComfyUI-Manager/check.sh" ] && chmod 755 ComfyUI-Manager/check.sh
  ![ -f "ComfyUI-Manager/scan.sh" ] && chmod 755 ComfyUI-Manager/scan.sh
  ![ -f "ComfyUI-Manager/node_db/dev/scan.sh" ] && chmod 755 ComfyUI-Manager/node_db/dev/scan.sh
  ![ -f "ComfyUI-Manager/scripts/install-comfyui-venv-linux.sh" ] && chmod 755 ComfyUI-Manager/scripts/install-comfyui-venv-linux.sh
  ![ -f "ComfyUI-Manager/scripts/install-comfyui-venv-win.bat" ] && chmod 755 ComfyUI-Manager/scripts/install-comfyui-venv-win.bat

  ![ ! -d ComfyUI-Manager ] && echo -= Initial setup ComfyUI-Manager =- && git clone https://github.com/ltdrdata/ComfyUI-Manager
  # %cd ComfyUI-Manager
  # !git pull

# %cd $WORKSPACE

if OPTIONS['INSTALL_CUSTOM_NODES_DEPENDENCIES']:
  # !echo -= Install custom nodes dependencies =-
  # !pip install GitPython
  # !python custom_nodes/ComfyUI-Manager/cm-cli.py restore-dependencies
  
  # %cd custom_nodes
  
  repositories = [
    "https://github.com/XmYx/deforum-comfy-nodes.git",
    "https://github.com/rgthree/rgthree-comfy",
    "https://github.com/a1lazydog/ComfyUI-AudioScheduler",
    "https://github.com/cubiq/ComfyUI_IPAdapter_plus",
    "https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite",
    "https://github.com/Kosinkadink/ComfyUI-Advanced-ControlNet",
    "https://github.com/WASasquatch/was-node-suite-comfyui",
    "https://github.com/11cafe/comfyui-workspace-manager",
    "https://github.com/cubiq/ComfyUI_essentials",
    "https://github.com/FizzleDorf/ComfyUI_FizzNodes",
    "https://github.com/ltdrdata/ComfyUI-Impact-Pack",
    "https://github.com/Fannovel16/ComfyUI-Frame-Interpolation",
    "https://github.com/Fannovel16/ComfyUI-Video-Matting",
    "https://github.com/crystian/ComfyUI-Crystools"
  ]

  for repo in repositories:
      # !git clone {repo}
# Out:
# /workspace/appz/ComfyUI
# -= Updating ComfyUI =-
# Already up to date.
# -= Install dependencies =-
# Requirement already satisfied: accelerate in /workspace/.miniconda3/lib/python3.11/site-packages (0.31.0)
# Requirement already satisfied: numpy>=1.17 in /workspace/.miniconda3/lib/python3.11/site-packages (from accelerate) (1.24.1)
# Requirement already satisfied: packaging>=20.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from accelerate) (23.0)
# Requirement already satisfied: psutil in /workspace/.miniconda3/lib/python3.11/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /workspace/.miniconda3/lib/python3.11/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /workspace/.miniconda3/lib/python3.11/site-packages (from accelerate) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /workspace/.miniconda3/lib/python3.11/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.9.0)
# Requirement already satisfied: typing-extensions in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.0)
# Requirement already satisfied: jinja2 in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2024.6.0)
# Requirement already satisfied: triton==2.1.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /workspace/.miniconda3/lib/python3.11/site-packages (from huggingface-hub->accelerate) (2.29.0)
# Requirement already satisfied: tqdm>=4.42.1 in /workspace/.miniconda3/lib/python3.11/site-packages (from huggingface-hub->accelerate) (4.51.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspace/.miniconda3/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.miniconda3/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /workspace/.miniconda3/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.miniconda3/lib/python3.11/site-packages (from requests->huggingface-hub->accelerate) (2024.6.2)
# Requirement already satisfied: mpmath>=0.19 in /workspace/.miniconda3/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in /workspace/.miniconda3/lib/python3.11/site-packages (2.1.0+cu118)
# Requirement already satisfied: torchvision in /workspace/.miniconda3/lib/python3.11/site-packages (0.16.0+cu118)
# Requirement already satisfied: torchaudio in /workspace/.miniconda3/lib/python3.11/site-packages (2.1.0+cu118)
# Requirement already satisfied: filelock in /workspace/.miniconda3/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in /workspace/.miniconda3/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /workspace/.miniconda3/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /workspace/.miniconda3/lib/python3.11/site-packages (from torch) (3.0)
# Requirement already satisfied: jinja2 in /workspace/.miniconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /workspace/.miniconda3/lib/python3.11/site-packages (from torch) (2024.6.0)
# Requirement already satisfied: triton==2.1.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from torch) (2.1.0)
# Requirement already satisfied: numpy in /workspace/.miniconda3/lib/python3.11/site-packages (from torchvision) (1.24.1)
# Requirement already satisfied: requests in /workspace/.miniconda3/lib/python3.11/site-packages (from torchvision) (2.29.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from torchvision) (9.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspace/.miniconda3/lib/python3.11/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.miniconda3/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /workspace/.miniconda3/lib/python3.11/site-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.miniconda3/lib/python3.11/site-packages (from requests->torchvision) (2024.6.2)
# Requirement already satisfied: mpmath>=0.19 in /workspace/.miniconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torchsde in /workspace/.miniconda3/lib/python3.11/site-packages (0.2.6)
# Requirement already satisfied: numpy>=1.19 in /workspace/.miniconda3/lib/python3.11/site-packages (from torchsde) (1.24.1)
# Requirement already satisfied: scipy>=1.5 in /workspace/.miniconda3/lib/python3.11/site-packages (from torchsde) (1.13.1)
# Requirement already satisfied: torch>=1.6.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from torchsde) (2.1.0+cu118)
# Requirement already satisfied: trampoline>=0.1.2 in /workspace/.miniconda3/lib/python3.11/site-packages (from torchsde) (0.1.2)
# Requirement already satisfied: filelock in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.6.0->torchsde) (3.9.0)
# Requirement already satisfied: typing-extensions in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.6.0->torchsde) (4.12.2)
# Requirement already satisfied: sympy in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.6.0->torchsde) (1.12)
# Requirement already satisfied: networkx in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.6.0->torchsde) (3.0)
# Requirement already satisfied: jinja2 in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.6.0->torchsde) (3.1.2)
# Requirement already satisfied: fsspec in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.6.0->torchsde) (2024.6.0)
# Requirement already satisfied: triton==2.1.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from torch>=1.6.0->torchsde) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /workspace/.miniconda3/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->torchsde) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /workspace/.miniconda3/lib/python3.11/site-packages (from sympy->torch>=1.6.0->torchsde) (1.3.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tqdm in /workspace/.miniconda3/lib/python3.11/site-packages (4.51.0)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# /workspace/appz/ComfyUI/custom_nodes
# /workspace/appz/ComfyUI/custom_nodes/ComfyUI-Manager
# Already up to date.
# /workspace/appz/ComfyUI
# -= Install custom nodes dependencies =-
# Requirement already satisfied: GitPython in /workspace/.miniconda3/lib/python3.11/site-packages (3.1.43)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /workspace/.miniconda3/lib/python3.11/site-packages (from GitPython) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /workspace/.miniconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython) (5.0.1)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Traceback (most recent call last):
#   File "/workspace/appz/ComfyUI/custom_nodes/ComfyUI-Manager/cm-cli.py", line 12, in <module>
#     import typer
# ModuleNotFoundError: No module named 'typer'
# /workspace/appz/ComfyUI/custom_nodes
# Cloning into 'deforum-comfy-nodes'...
# remote: Enumerating objects: 1000, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 1000 (delta 109), reused 105 (delta 47), pack-reused 821
# Receiving objects: 100% (1000/1000), 291.70 KiB | 3.79 MiB/s, done.
# Resolving deltas: 100% (678/678), done.
# Cloning into 'rgthree-comfy'...
# remote: Enumerating objects: 2759, done.
# remote: Counting objects: 100% (896/896), done.
# remote: Compressing objects: 100% (317/317), done.
# remote: Total 2759 (delta 614), reused 798 (delta 579), pack-reused 1863
# Receiving objects: 100% (2759/2759), 169.29 MiB | 31.30 MiB/s, done.
# Resolving deltas: 100% (1964/1964), done.
# Cloning into 'ComfyUI-AudioScheduler'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (63/63), done.
# remote: Total 140 (delta 43), reused 58 (delta 22), pack-reused 55
# Receiving objects: 100% (140/140), 87.87 MiB | 23.25 MiB/s, done.
# Resolving deltas: 100% (63/63), done.
# Cloning into 'ComfyUI_IPAdapter_plus'...
# remote: Enumerating objects: 703, done.
# remote: Counting objects: 100% (375/375), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 703 (delta 341), reused 276 (delta 259), pack-reused 328
# Receiving objects: 100% (703/703), 4.70 MiB | 30.63 MiB/s, done.
# Resolving deltas: 100% (473/473), done.
# Cloning into 'ComfyUI-VideoHelperSuite'...
# remote: Enumerating objects: 1552, done.
# remote: Counting objects: 100% (659/659), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 1552 (delta 514), reused 530 (delta 437), pack-reused 893
# Receiving objects: 100% (1552/1552), 389.49 KiB | 3.48 MiB/s, done.
# Resolving deltas: 100% (858/858), done.
# Cloning into 'ComfyUI-Advanced-ControlNet'...
# remote: Enumerating objects: 768, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 768 (delta 132), reused 95 (delta 78), pack-reused 600
# Receiving objects: 100% (768/768), 289.92 KiB | 3.41 MiB/s, done.
# Resolving deltas: 100% (528/528), done.
# Cloning into 'was-node-suite-comfyui'...
# remote: Enumerating objects: 2131, done.
# remote: Counting objects: 100% (719/719), done.
# remote: Compressing objects: 100% (264/264), done.
# remote: Total 2131 (delta 539), reused 581 (delta 450), pack-reused 1412
# Receiving objects: 100% (2131/2131), 39.63 MiB | 23.60 MiB/s, done.
# Resolving deltas: 100% (1303/1303), done.
# Cloning into 'comfyui-workspace-manager'...
# remote: Enumerating objects: 10373, done.
# remote: Counting objects: 100% (4113/4113), done.
# remote: Compressing objects: 100% (1133/1133), done.
# remote: Total 10373 (delta 3265), reused 3590 (delta 2919), pack-reused 6260
# Receiving objects: 100% (10373/10373), 18.11 MiB | 22.89 MiB/s, done.
# Resolving deltas: 100% (7560/7560), done.
# Cloning into 'ComfyUI_essentials'...
# remote: Enumerating objects: 260, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 260 (delta 80), reused 84 (delta 65), pack-reused 158
# Receiving objects: 100% (260/260), 82.48 KiB | 2.29 MiB/s, done.
# Resolving deltas: 100% (151/151), done.
# Cloning into 'ComfyUI_FizzNodes'...
# remote: Enumerating objects: 582, done.
# remote: Counting objects: 100% (229/229), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 582 (delta 194), reused 189 (delta 171), pack-reused 353
# Receiving objects: 100% (582/582), 157.87 KiB | 3.16 MiB/s, done.
# Resolving deltas: 100% (367/367), done.
# Cloning into 'ComfyUI-Impact-Pack'...
# remote: Enumerating objects: 4259, done.
# remote: Counting objects: 100% (1287/1287), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 4259 (delta 1230), reused 1155 (delta 1129), pack-reused 2972
# Receiving objects: 100% (4259/4259), 31.69 MiB | 27.71 MiB/s, done.
# Resolving deltas: 100% (2868/2868), done.
# Cloning into 'ComfyUI-Frame-Interpolation'...
# remote: Enumerating objects: 1021, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 1021 (delta 118), reused 113 (delta 113), pack-reused 897
# Receiving objects: 100% (1021/1021), 79.74 MiB | 29.77 MiB/s, done.
# Resolving deltas: 100% (596/596), done.
# Cloning into 'ComfyUI-Video-Matting'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 109 (delta 49), reused 59 (delta 20), pack-reused 0
# Receiving objects: 100% (109/109), 590.71 KiB | 9.09 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# Cloning into 'ComfyUI-Crystools'...
# remote: Enumerating objects: 988, done.
# remote: Counting objects: 100% (316/316), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 988 (delta 195), reused 272 (delta 194), pack-reused 672
# Receiving objects: 100% (988/988), 15.09 MiB | 23.34 MiB/s, done.
# Resolving deltas: 100% (577/577), done.

# %% [markdown]
# # Models

# %% [markdown]
# Download some models/checkpoints/vae or custom comfyui nodes (uncomment the commands for the ones you want)

# %% [markdown]
# ### Vars

# %%
# Define lists for different types of assets
checkpoints_models = [
    "https://huggingface.co/stabilityai/stable-diffusion-3-medium/resolve/main/sd3_medium.safetensors",
    "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors",
    "https://huggingface.co/stabilityai/stable-diffusion-xl-refiner-1.0/resolve/main/sd_xl_refiner_1.0.safetensors",
    "https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt",
    "https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.safetensors",
    "https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.safetensors",
    "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors",
    "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A1_orangemixs.safetensors",
    "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A3_orangemixs.safetensors",
    "https://huggingface.co/Linaqruf/anything-v3.0/resolve/main/anything-v3-fp16-pruned.safetensors",
    "https://huggingface.co/waifu-diffusion/wd-1-5-beta3/resolve/main/wd-illusion-fp16.safetensors",
    "https://huggingface.co/comfyanonymous/illuminatiDiffusionV1_v11_unCLIP/resolve/main/illuminatiDiffusionV1_v11-unclip-h-fp16.safetensors",
    "https://huggingface.co/comfyanonymous/wd-1.5-beta2_unCLIP/resolve/main/wd-1-5-beta2-aesthetic-unclip-h-fp16.safetensors",
]

video_checkpoints_models = [
    "https://huggingface.co/stabilityai/stable-video-diffusion-img2vid/resolve/main/svd.safetensors"
]

vae_models = [
    "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors",
    "https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt",
    "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt",
]

loras_models = [
    "https://civitai.com/api/download/models/10350",
    "https://civitai.com/api/download/models/10638",
    "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors",
]

t2i_adapters_models = [
    "https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_depth_sd14v1.pth",
    "https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_seg_sd14v1.pth",
    "https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_sketch_sd14v1.pth",
    "https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_keypose_sd14v1.pth",
    "https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_openpose_sd14v1.pth",
    "https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_color_sd14v1.pth",
    "https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_canny_sd14v1.pth",
    "https://huggingface.co/TencentARC/T2I-Adapter/resolve/main/models/t2iadapter_style_sd14v1.pth",
    "https://huggingface.co/openai/clip-vit-large-patch14/resolve/main/pytorch_model.bin",
]

controlnet_models = [
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_canny_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_lineart_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_openpose_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_scribble_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_seg_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15_softedge_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors",
    "https://huggingface.co/comfyanonymous/ControlNet-v1-1_fp16_safetensors/resolve/main/control_v11u_sd15_tile_fp16.safetensors",
    "https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-canny-rank256.safetensors",
    "https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-depth-rank256.safetensors",
    "https://huggingface.co/stabilityai/control-lora/resolve/main/control-LoRAs-rank256/control-lora-recolor-rank256.safetensors",
]

gligen_models = [
    "https://huggingface.co/comfyanonymous/GLIGEN_pruned_safetensors/resolve/main/gligen_sd14_textbox_pruned_fp16.safetensors",
]

esrgan_models = [
    "https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth",
    "https://huggingface.co/sberbank-ai/Real-ESRGAN/resolve/main/RealESRGAN_x2.pth",
    "https://huggingface.co/sberbank-ai/Real-ESRGAN/resolve/main/RealESRGAN_x4.pth",
]

all_models = {
    "checkpoints_models": checkpoints_models,
    "video_checkpoints_models": video_checkpoints_models,
    "vae_models": vae_models,
    "loras_models": loras_models,
    "t2i_adapters_models": t2i_adapters_models,
    "controlnet_models": controlnet_models,
    "gligen_models": gligen_models,
    "esrgan_models": esrgan_models
}

# Define target directories for each type of asset
target_dirs = {
    "checkpoints_models": "./models/checkpoints/",
    "video_checkpoints_models": "./models/checkpoints/",
    "vae_models": "./models/vae/",
    "loras_models": "./models/loras/",
    "t2i_adapters_models": "./models/controlnet/",
    "controlnet_models": "./models/controlnet/",
    "gligen_models": "./models/gligen/",
    "esrgan_models": "./models/upscale_models/"
}

# %% [markdown]
# ### Functions

# %%
from tqdm import tqdm
import requests
import os

# Function to download files
def download_file(url, output_dir, force = False):
    os.makedirs(output_dir, exist_ok=True)
    local_filename = os.path.join(output_dir, url.split("/")[-1])
    
    if os.path.exists(local_filename) and force == False:
        print(f"{local_filename} from {url} already exists.")
        return

    response = requests.get(url, stream=True)
    total_size = int(response.headers.get('content-length', 0))
    
    pprint(f"Downloading from {model_url}...\n")
    
    with open(local_filename, 'wb') as f, tqdm(
        desc=local_filename,
        total=total_size,
        unit='iB',
        unit_scale=True,
        unit_divisor=1024,
    ) as bar:
        for data in response.iter_content(chunk_size=1024):
            size = f.write(data)
            bar.update(size)
            
    pprint("Download complete.")        

# Pretty print
def pprint(*args):
    for arg in args:
        if isinstance(arg, dict):
            for key, value in arg.items():
                print(f"{key}:")
                pprint(value)  # Recursive call for nested structures
        elif isinstance(arg, list):
            for item in arg:
                pprint(item)  # Recursive call for nested structures
        else:
            print(arg)

# %% [markdown]
# ### Download

# %%
# %cd /workspace/appz/ComfyUI




# Download selected assets
_selected = [ 
    video_checkpoints_models[0]
]

FORCE=False

for model_url in _selected:
    for model_type, target_dir in target_dirs.items():
        if model_url in all_models[model_type]:           
           download_file(model_url, target_dir, FORCE)           
           break
# Out:
# /workspace/appz/ComfyUI
# ./models/checkpoints/svd.safetensors:   0%|          | 0.00/8.90G [00:00<?, ?iB/s]
# Downloading from https://huggingface.co/stabilityai/stable-video-diffusion-img2vid/resolve/main/svd.safetensors...
# ./models/checkpoints/svd.safetensors: 100%|██████████| 8.90G/8.90G [01:09<00:00, 137MiB/s]
# Download complete.

# %% [markdown]
# # Run

# %% [markdown]
# ## Run ComfyUI with localtunnel

# %% [markdown]
# #### NVM

# %%
import os

# Set environment variables
os.environ['NODE_VERSION'] = '21.4.0'
os.environ['NVM_DIR'] = f"/workspace/.nvm"

# Create the NVM directory
os.makedirs(os.environ['NVM_DIR'], exist_ok=True)

# Check if nvm is already installed
nvm_sh_path = os.path.join(os.environ['NVM_DIR'], "nvm.sh")

if not os.path.exists(nvm_sh_path):
    # Download and install nvm
    # !curl -o- https://raw.githubusercontent.com/nvm-sh/nvm/v0.38.0/install.sh | bash

# Edit ~/.bashrc to include nvm initialization script if it doesn't already exist
bashrc_path = os.path.expanduser("~/.bashrc")
nvm_init_script = f"""
export NVM_DIR="{os.environ['NVM_DIR']}"
[ -s "$NVM_DIR/nvm.sh" ] && \. "$NVM_DIR/nvm.sh"
[ -s "$NVM_DIR/bash_completion" ] && \. "$NVM_DIR/bash_completion"
"""

# Check if the initialization script already exists in ~/.bashrc
with open(bashrc_path, "r") as bashrc:
    bashrc_content = bashrc.read()

if nvm_init_script.strip() not in bashrc_content:
    with open(bashrc_path, "a") as bashrc:
        bashrc.write("\n" + nvm_init_script)
    print("nvm initialization script added to ~/.bashrc")
else:
    print("nvm initialization script already exists in ~/.bashrc")

# Source nvm and run Node.js commands in a single cell
# !bash -c " \
{nvm_init_script} \
nvm install {os.environ['NODE_VERSION']}; \
nvm use {os.environ['NODE_VERSION']}; \
nvm alias default {os.environ['NODE_VERSION']}"

# %% [markdown]
# ### EXEC

# %%
import subprocess
import threading
import time
import socket
import urllib.request

WEB_PORT=8188

# !bash -c " \
{nvm_init_script} \
npm install -g localtunnel"

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch localtunnel (if it gets stuck here localtunnel is having issues)\n")

  print("The password/enpoint ip for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))  
  
  # !bash -c " \
    {nvm_init_script} \
    lt --port {port}"


threading.Thread(target=iframe_thread, daemon=True, args=(WEB_PORT,)).start()

# !python main.py --dont-print-server
# Out:
# ^C
#
# Stopped server

# %%
#Install cloudflared
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# %%
import subprocess
import threading
import time
import socket
import urllib.request

PORT=8188

def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  print("\nComfyUI finished loading, trying to launch cloudflared (if it gets stuck here cloudflared is having issues)\n")

  p = subprocess.Popen(["cloudflared", "tunnel", "--url", "http://127.0.0.1:{}".format(port)], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
  for line in p.stderr:
    l = line.decode()
    if "trycloudflare.com " in l:
      print("This is the URL to access ComfyUI:", l[l.find("http"):], end='')
    #print(l, end='')


threading.Thread(target=iframe_thread, daemon=True, args=(PORT,)).start()

# !python main.py --dont-print-server

# %% [markdown]
# ## Run ComfyUI with colab iframe

# %% [markdown]
# You should see the ui appear in an iframe. If you get a 403 error, it's your firefox settings or an extension that's messing things up.
#
# If you want to open it in another window use the link.
#
# Note that some UI features like live image previews won't work because the colab iframe blocks websockets.

# %%
import threading
import time
import socket
def iframe_thread(port):
  while True:
      time.sleep(0.5)
      sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
      result = sock.connect_ex(('127.0.0.1', port))
      if result == 0:
        break
      sock.close()
  from google.colab import output
  output.serve_kernel_port_as_iframe(port, height=1024)
  print("to open it in a window you can open this link here:")
  output.serve_kernel_port_as_window(port)

threading.Thread(target=iframe_thread, daemon=True, args=(8188,)).start()

# !python main.py --dont-print-server
